# %% [markdown]
# # 1. Icebreaker & Vorstellung
# ## Erste Ausgaben mit print()

# %%
print("Hallo")
# Out:
# Hallo

# %% [markdown]
# `print()` ist die einfachste Möglichkeit, etwas in Python auszugeben – zum Beispiel Texte, Zahlen oder Emojis."

# %%
# Einfacher Text
print("Hallo! Willkommen zu unserem Python Workshop!")
# Out:
# Hallo! Willkommen zu unserem Python Workshop!

# %%
# Text mit Namen
name = "Hilal"
print("Hallo, mein Name ist", name)
# Out:
# Hallo, mein Name ist Hilal

# %%
# Text und Zahl
alter = 37
print("Ich bin", alter, "Jahre alt.")
# Out:
# Ich bin 37 Jahre alt.

# %% [markdown]
# ## Schritt 2: Emojis in print() einfügen

# %%
print("Ich liebe Programmieren! 💻")
# Out:
# Ich liebe Programmieren! 💻

# %%
print("Heute lernen wir über inspirierende Frauen! 👩‍💻🌟")
# Out:
# Heute lernen wir über inspirierende Frauen! 👩‍💻🌟

# %%
print("Python macht Spaß! 🐍✨")
# Out:
# Python macht Spaß! 🐍✨

# %%
print("Ich liebe Programmieren! 💻")
print("Heute lernen wir über inspirierende Frauen! 👩‍💻🌟")
print("Python macht Spaß! 🐍✨")
# Out:
# Ich liebe Programmieren! 💻
# Heute lernen wir über inspirierende Frauen! 👩‍💻🌟
# Python macht Spaß! 🐍✨

# %% [markdown]
# ## Du bist dran!

# %% [markdown]
# ### Jetzt kannst du dich selbst vorstellen mit Python 🐍✨

# %% [markdown]
# Tipp: Ihr könnt Emojis kopieren von z.B.:
# https://emojipedia.org/

# %% [markdown]
# ### Name

# %%
name = "..."
print("Hallo! Mein Name ist", name, "👋")

# %% [markdown]
# ### Alter

# %%
age = ...
print("Ich bin", age, "Jahre alt.")

# %% [markdown]
# ### Hobby

# %%
hobby = "..."
print("Mein Hobby ist:", hobby)

# %% [markdown]
# ## Schritt 3: Bilder einfügen – Warum wir Hilfe brauchen
#
# Nicht alles, was wir uns vorstellen, existiert automatisch in Python. 😔
# Zum Beispiel: Python kann Text direkt ausgeben, aber Bilder oder andere Medien müssen wir ein bisschen vorbereiten.
#
# Glücklicherweise haben andere Menschen uns Hilfen vorbereitet, damit wir Bilder und Inhalte einfach einfügen können.
# Dazu nutzen wir die Bibliothek IPython.display und die Funktion Image.

# %%
from IPython.display import Image, display

# Beispiel: Alica Schmidt – deutsche Leichtathletin
display(Image(url="https://upload.wikimedia.org/wikipedia/commons/thumb/3/3c/2022-02-27_Leichtathletik%2C_Deutsche_Hallenmeisterschaften_1DX_5169_by_Stepro.jpg/960px-2022-02-27_Leichtathletik%2C_Deutsche_Hallenmeisterschaften_1DX_5169_by_Stepro.jpg"))

print("Alica Schmidt: Deutsche Sprinterin, bekannt für ihre Leistungen im Sport und große Social‑Media‑Reichweite.")
# Out:
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/3/3c/2022-02-27_Leichtathletik%2C_Deutsche_Hallenmeisterschaften_1DX_5169_by_Stepro.jpg/960px-2022-02-27_Leichtathletik%2C_Deutsche_Hallenmeisterschaften_1DX_5169_by_Stepro.jpg"/>
# Alica Schmidt: Deutsche Sprinterin, bekannt für ihre Leistungen im Sport und große Social‑Media‑Reichweite.

# %% [markdown]
# ## Du bist dran!

# %%
# =========================================
# Dein persönliches Vorstellungscoding 🎉
# Fülle die Lücken aus und zeige dein Lieblingsding
# =========================================

from IPython.display import Image, display

# -------------------------------
# Deine Angaben
# -------------------------------

# Name
name = "..."  # z.B. Aysha
print("Hallo! Mein Name ist", name, "👋")

# Alter
alter = "..."  # z.B. 12
print("Ich bin", alter, "Jahre alt.")

# Lieblingshobby
hobby = "..."  # z.B. Tanzen 💃
print("Mein Lieblingshobby ist:", hobby)

# Lieblingsfarbe
farbe = "..."  # z.B. Blau 💙
print("Meine Lieblingsfarbe ist:", farbe)

# Lieblingstier
tier = "..."  # z.B. Katze 🐱
print("Mein Lieblingstier ist:", tier)

# Lieblingssportlerin / Schauspielerin / Rapperin / Hobby / etc.
lieblings_person = "..."  # z.B. Alica Schmidt
print("Meine Lieblings.... ist:", lieblings_person, "🌟")


# -------------------------------
# Bild von Lieblingsperson / Hobby / Tier / Farbe
# -------------------------------

# Hinweis: Hier den Link zum Bild einfügen
bild_url = "..."  
display(Image(url=bild_url))

# Optional: kurze Info über das Bild oder die Person
print("Kurze Info über meine Lieblingsperson / mein Lieblingshobby / Lieblingstier:")
print("...")
