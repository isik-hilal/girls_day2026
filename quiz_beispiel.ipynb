# %%
from IPython.display import Image, display

print("🎉 Rate die inspirierende Frau! 🎉")
print("\nRunde 1: Historische Computerpionierin")

print("\nHinweise:")
print("1. Sie gilt als erste Programmiererin.")
print("2. Sie schrieb einen Algorithmus für Charles Babbages Maschine.")
print("3. Sie lebte im 19. Jahrhundert.\n")

print("Wer ist sie?")
print("A: Ada Lovelace")
print("B: Grace Hopper")
print("C: Marie Curie")

antwort = input("Deine Antwort (A/B/C): ").upper()

if antwort == "A":
    print("✅ Richtig! Es ist Ada Lovelace!")
else:
    print("❌ Falsch! Die richtige Antwort ist Ada Lovelace.")

print("\nWarum sie wichtig ist:")
print("👉 Sie stellte sich Computer vor, die mehr als nur rechnen konnten.")
print("👉 Sie schrieb den ersten Algorithmus für eine Maschine.\n")

display(Image(url="https://upload.wikimedia.org/wikipedia/commons/a/a4/Ada_Lovelace_portrait.jpg"))

# Infos zu den anderen Antworten
print("\nKurze Infos zu den anderen Frauen:")
print("Grace Hopper: US-amerikanische Informatikerin, arbeitete an frühen Programmiersprachen.")
print("Marie Curie: Polnisch-französische Wissenschaftlerin, bekannt für Forschung zur Radioaktivität.\n")

print("💡 Motivation: Wenn Ada programmieren konnte, kannst du es auch! 💻👩‍💻")
# Out:
# 🎉 Rate die inspirierende Frau! 🎉
#
# Runde 1: Historische Computerpionierin
#
# Hinweise:
# 1. Sie gilt als erste Programmiererin.
# 2. Sie schrieb einen Algorithmus für Charles Babbages Maschine.
# 3. Sie lebte im 19. Jahrhundert.
#
# Wer ist sie?
# A: Ada Lovelace
# B: Grace Hopper
# C: Marie Curie
# Deine Antwort (A/B/C):  A
# ✅ Richtig! Es ist Ada Lovelace!
#
# Warum sie wichtig ist:
# 👉 Sie stellte sich Computer vor, die mehr als nur rechnen konnten.
# 👉 Sie schrieb den ersten Algorithmus für eine Maschine.
# <img src="https://upload.wikimedia.org/wikipedia/commons/a/a4/Ada_Lovelace_portrait.jpg"/>
# Kurze Infos zu den anderen Frauen:
# Grace Hopper: US-amerikanische Informatikerin, arbeitete an frühen Programmiersprachen.
# Marie Curie: Polnisch-französische Wissenschaftlerin, bekannt für Forschung zur Radioaktivität.
#
# 💡 Motivation: Wenn Ada programmieren konnte, kannst du es auch! 💻👩‍💻

# %%
from IPython.display import Image, display
import time

print("🎉 Rate die inspirierende Frau! 🎉")
print("\nRunde 2: Moderne KI-Innovatorin")

print("\nHinweise:")
time.sleep(1)
print("1. Sie ist Informatikerin aus Ägypten.")
time.sleep(1)
print("2. Sie arbeitet an KI, die menschliche Emotionen erkennt.")
time.sleep(1)
print("3. Sie gründete die Firma Affectiva.\n")

print("Wer ist sie?")
print("A: Rana el Kaliouby")
print("B: Fei-Fei Li")
print("C: Timnit Gebru")

antwort = input("Deine Antwort (A/B/C): ").upper()

if antwort == "A":
    print("✅ Richtig! Es ist Rana el Kaliouby!")
else:
    print("❌ Falsch! Die richtige Antwort ist Rana el Kaliouby.")

print("\nWarum sie wichtig ist:")
print("👉 Sie half, KI zu entwickeln, die Emotionen lesen kann.")
print("👉 Sie setzt sich für ethische KI ein.\n")

display(Image(url="https://upload.wikimedia.org/wikipedia/commons/thumb/7/77/Rana_el_Kaliouby.jpg/960px-Rana_el_Kaliouby.jpg"))

# Infos zu den anderen Antworten
print("\nKurze Infos zu den anderen Frauen:")
print("Fei-Fei Li: Chinesisch-amerikanische Informatikerin, bekannt für Bildverarbeitungs-KI (ImageNet).")
print("Timnit Gebru: Informatikerin mit äthiopischen Wurzeln, kämpft für faire KI und Ethik in der Technologie.\n")

print("💡 Motivation: Du kannst Technik gestalten, die Menschen hilft! 🤖💖")
# Out:
# 🎉 Rate die inspirierende Frau! 🎉
#
# Runde 2: Moderne KI-Innovatorin
#
# Hinweise:
# 1. Sie ist Informatikerin aus Ägypten.
# 2. Sie arbeitet an KI, die menschliche Emotionen erkennt.
# 3. Sie gründete die Firma Affectiva.
#
# Wer ist sie?
# A: Rana el Kaliouby
# B: Fei-Fei Li
# C: Timnit Gebru
# Deine Antwort (A/B/C):  A
# ✅ Richtig! Es ist Rana el Kaliouby!
#
# Warum sie wichtig ist:
# 👉 Sie half, KI zu entwickeln, die Emotionen lesen kann.
# 👉 Sie setzt sich für ethische KI ein.
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/7/77/Rana_el_Kaliouby.jpg/960px-Rana_el_Kaliouby.jpg"/>
# Kurze Infos zu den anderen Frauen:
# Fei-Fei Li: Chinesisch-amerikanische Informatikerin, bekannt für Bildverarbeitungs-KI (ImageNet).
# Timnit Gebru: Informatikerin mit äthiopischen Wurzeln, kämpft für faire KI und Ethik in der Technologie.
#
# 💡 Motivation: Du kannst Technik gestalten, die Menschen hilft! 🤖💖
